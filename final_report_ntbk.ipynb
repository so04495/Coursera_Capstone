# %%
import requests
import json
import numpy as np
from pandas.io.json import json_normalize
import folium as f

# %%
url = 'https://cocl.us/new_york_dataset'
nyd = requests.get(url).json()

# %%
df = json_normalize(nyd['features'])
del df['id']
del df['type']
del df['geometry_name']
df = df[df['geometry.type'] == 'Point']
del df['properties.annoline1']
del df['properties.annoline2']
del df['properties.annoline3']
del df['properties.annoangle']
del df['properties.bbox']
df['geometry.coordinates'] = df['geometry.coordinates'].astype(str)
df[['Lat', 'Lon']] = df['geometry.coordinates'].str.strip(r'[]').str.split(',', expand=True).astype(np.float)
del df['geometry.coordinates']
df
# Out:
#     geometry.type properties.name  properties.stacked properties.borough  \
# 0           Point       Wakefield                   1              Bronx
# 1           Point      Co-op City                   2              Bronx
# 2           Point     Eastchester                   1              Bronx
# 3           Point       Fieldston                   1              Bronx
# 4           Point       Riverdale                   1              Bronx
# ..            ...             ...                 ...                ...
# 301         Point    Hudson Yards                   2          Manhattan
# 302         Point         Hammels                   1             Queens
# 303         Point       Bayswater                   1             Queens
# 304         Point    Queensbridge                   1             Queens
# 305         Point       Fox Hills                   2      Staten Island
#
#            Lat        Lon
# 0   -73.847201  40.894705
# 1   -73.829939  40.874294
# ...

# %%
map1 = f.Map(location=[40.8, -74], tiles='Stamen Terrain')
for i, e in df.iterrows():
    f.CircleMarker(
        location=[e['Lon'], e['Lat']],
        radius=1,
        color="green"
    ).add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...
